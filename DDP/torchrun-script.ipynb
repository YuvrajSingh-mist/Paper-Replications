# %%
# !pip install torchtune
# !pip install torchao
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 47.2 MB/s eta 0:00:00a 0:00:01
# ...

# %%
! cp /kaggle/input/scriptv12/multi.py .
! ls .
# Out:
# multi.py  state.db

# %%
# !pwd
# !torchrun --standalone --nproc_per_node=gpu  multi.py
# Out:
# /kaggle/working
# W0210 10:16:18.507000 122 torch/distributed/run.py:793]
# W0210 10:16:18.507000 122 torch/distributed/run.py:793] *****************************************
# W0210 10:16:18.507000 122 torch/distributed/run.py:793] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# W0210 10:16:18.507000 122 torch/distributed/run.py:793] *****************************************
# import error: No module named 'triton'
# import error: No module named 'triton'
# World size: 2
# World size: 2
# Start running basic DDP example on rank 0.
# Start running basic DDP example on rank 1.
# Starting the initial train...
# ...
# Training:  10%|█▌             | 1/10 [1:41:38<9:11:33, 3677.02s/it, loss=2.4782]
